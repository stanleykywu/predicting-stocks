# %%
import pandas as pd
import numpy as np
import datetime

# %%
total_df = pd.read_csv('News Sentiment/news_sentiment.csv')

# %%
dates = [datetime.datetime(int(x.split('/')[3]), int(x.split('/')[4]), int(x.split('/')[5])) for x in total_df['url']]
total_df['Date'] = dates

total_df.columns
# Out:
# Index(['url', 'timedelta', 'n_tokens_title', 'n_tokens_content',
#        'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens',
#        'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos',
#        'average_token_length', 'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
# ...

# %%
df = total_df[['Date', 'data_channel_is_lifestyle',
       'data_channel_is_entertainment', 'data_channel_is_bus',
       'data_channel_is_socmed', 'data_channel_is_tech',
       'data_channel_is_world', 'global_subjectivity', 'global_sentiment_polarity', 'global_rate_positive_words',
       'global_rate_negative_words', 'rate_positive_words',
       'rate_negative_words', 'avg_positive_polarity', 'min_positive_polarity',
       'max_positive_polarity', 'avg_negative_polarity',
       'min_negative_polarity', 'max_negative_polarity', 'title_subjectivity',
       'title_sentiment_polarity', 'abs_title_subjectivity',
       'abs_title_sentiment_polarity', 'shares']]

df.head()
# Out:
#         Date  data_channel_is_lifestyle  data_channel_is_entertainment  \
# 0 2013-01-07                          0                              1
# 1 2013-01-07                          0                              0
# 2 2013-01-07                          0                              0
# 3 2013-01-07                          0                              1
# 4 2013-01-07                          0                              0
#
#    data_channel_is_bus  data_channel_is_socmed  data_channel_is_tech  \
# 0                    0                       0                     0
# 1                    1                       0                     0
# 2                    1                       0                     0
# 3                    0                       0                     0
# 4                    0                       0                     1
#
#    data_channel_is_world  global_subjectivity  global_sentiment_polarity  \
# ...

# %%
df_gp_date = df.groupby('Date',as_index=False).mean()

df_gp_date.head()
# Out:
#         Date  data_channel_is_lifestyle  data_channel_is_entertainment  \
# 0 2013-01-07                   0.101266                       0.088608
# 1 2013-01-08                   0.083333                       0.166667
# 2 2013-01-09                   0.134831                       0.191011
# 3 2013-01-10                   0.125000                       0.187500
# 4 2013-01-11                   0.098039                       0.137255
#
#    data_channel_is_bus  data_channel_is_socmed  data_channel_is_tech  \
# 0             0.113924                0.050633              0.455696
# 1             0.083333                0.000000              0.416667
# 2             0.112360                0.033708              0.235955
# 3             0.200000                0.012500              0.237500
# 4             0.078431                0.058824              0.333333
#
#    data_channel_is_world  global_subjectivity  global_sentiment_polarity  \
# ...

# %%
google_data = pd.read_csv('Stocks/googl.us.txt')

google_data.head()
# Out:
#          Date    Open   High     Low   Close    Volume  OpenInt
# 0  2004-08-19  50.000  52.03  47.980  50.170  44703800        0
# 1  2004-08-20  50.505  54.54  50.250  54.155  22857200        0
# 2  2004-08-23  55.375  56.74  54.525  54.700  18274400        0
# 3  2004-08-24  55.620  55.80  51.785  52.435  15262600        0
# 4  2004-08-25  52.480  54.00  51.940  53.000   9197800        0

# %%
df = df_gp_date.set_index('Date').join(google_data.set_index('Date'))

df.head()
# Out:
#             data_channel_is_lifestyle  data_channel_is_entertainment  \
# Date
# 2013-01-07                   0.101266                       0.088608
# 2013-01-08                   0.083333                       0.166667
# 2013-01-09                   0.134831                       0.191011
# 2013-01-10                   0.125000                       0.187500
# 2013-01-11                   0.098039                       0.137255
#
#             data_channel_is_bus  data_channel_is_socmed  data_channel_is_tech  \
# Date
# 2013-01-07             0.113924                0.050633              0.455696
# 2013-01-08             0.083333                0.000000              0.416667
# 2013-01-09             0.112360                0.033708              0.235955
# 2013-01-10             0.200000                0.012500              0.237500
# 2013-01-11             0.078431                0.058824              0.333333
#
#             data_channel_is_world  global_subjectivity  \
# Date
# ...

# %%
df.to_csv('news_sentiment_augmented_google.csv')
