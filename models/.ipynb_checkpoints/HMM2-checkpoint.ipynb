# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('dataset/news_sentiment_augmented_google.csv').drop(['Unnamed: 0'], axis=1)
df['Middle'] = (df['Low'] + df['High']) / 2
df
# Out:
#            Date  data_channel_is_lifestyle  data_channel_is_entertainment  \
# 0      1/7/2013                   0.101266                       0.088608
# 1      1/8/2013                   0.083333                       0.166667
# 2      1/9/2013                   0.134831                       0.191011
# 3     1/10/2013                   0.125000                       0.187500
# 4     1/11/2013                   0.098039                       0.137255
# ..          ...                        ...                            ...
# 493  12/19/2014                   0.067568                       0.121622
# 494  12/22/2014                   0.097222                       0.097222
# 495  12/23/2014                   0.049180                       0.163934
# 496  12/24/2014                   0.057692                       0.115385
# 497  12/26/2014                   0.073171                       0.073171
#
#      data_channel_is_bus  data_channel_is_socmed  data_channel_is_tech  \
# 0               0.113924                0.050633              0.455696
# 1               0.083333                0.000000              0.416667
# 2               0.112360                0.033708              0.235955
# 3               0.200000                0.012500              0.237500
# 4               0.078431                0.058824              0.333333
# ..                   ...                     ...                   ...
# 493             0.121622                0.040541              0.081081
# 494             0.125000                0.013889              0.083333
# 495             0.032787                0.016393              0.131148
# 496             0.076923                0.057692              0.115385
# 497             0.097561                0.000000              0.121951
#
#      data_channel_is_world  global_subjectivity  global_sentiment_polarity  \
# 0                 0.113924             0.480690                   0.176541
# 1                 0.166667             0.455641                   0.161938
# 2                 0.123596             0.467116                   0.145615
# 3                 0.062500             0.462260                   0.156578
# 4                 0.156863             0.480836                   0.166839
# ..                     ...                  ...                        ...
# 493               0.432432             0.349775                   0.093596
# 494               0.319444             0.384586                   0.092461
# 495               0.377049             0.377784                   0.065058
# 496               0.423077             0.352430                   0.079892
# 497               0.463415             0.383164                   0.085894
#
#      global_rate_positive_words  ...  abs_title_subjectivity  \
# 0                      0.052167  ...                0.329081
# 1                      0.048414  ...                0.338889
# 2                      0.046497  ...                0.385071
# 3                      0.047305  ...                0.389721
# 4                      0.043516  ...                0.329093
# ..                          ...  ...                     ...
# 493                    0.029660  ...                0.340203
# 494                    0.029623  ...                0.335687
# 495                    0.030542  ...                0.316924
# 496                    0.027218  ...                0.363923
# 497                    0.028703  ...                0.305868
#
#      abs_title_sentiment_polarity       shares    Open    High     Low  \
# 0                        0.176808  2004.556962  367.72  369.69  365.29
# 1                        0.102778  1493.583333  367.77  368.15  362.22
# 2                        0.159139  2536.303371  366.50  369.18  364.30
# 3                        0.096425  2085.200000  371.42  372.50  366.75
# 4                        0.186686  3621.843137  371.00  371.22  368.15
# ..                            ...          ...     ...     ...     ...
# 493                      0.138859  2476.770270  516.99  520.81  508.86
# 494                      0.181722  2348.555556  520.61  532.97  520.59
# 495                      0.136902  2862.983607  534.51  542.30  533.72
# 496                      0.132746  3544.038462  538.82  540.29  535.10
# 497                      0.189816  3072.975610  536.93  543.25  535.49
#
#       Close   Volume  OpenInt   Middle
# 0    367.38  3311534        0  367.490
# 1    366.65  3352074        0  365.185
# 2    369.06  4051302        0  366.740
# 3    370.74  3671560        0  369.625
# 4    370.00  2570250        0  369.685
# ..      ...      ...      ...      ...
# 493  520.04  4872059        0  514.835
# 494  532.30  3319461        0  526.780
# 495  538.77  2877208        0  538.010
# 496  536.93   737848        0  537.695
# 497  541.52  1113464        0  539.370
#
# [498 rows x 31 columns]

# %%
plt.figure(figsize = (30,9))
plt.plot(range(df.shape[0]), df['Middle'])
plt.xticks(range(0, df.shape[0], 359), df['Date'].loc[::30])
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.show()

# %%
df = df[['Open', 'High', 'Low', 'Close']]
df.head()
# Out:
#      Open    High     Low   Close
# 0  367.72  369.69  365.29  367.38
# 1  367.77  368.15  362.22  366.65
# 2  366.50  369.18  364.30  369.06
# 3  371.42  372.50  366.75  370.74
# 4  371.00  371.22  368.15  370.00

# %%
training_data = df[:300]
validation_data = df[300:400]
testing_data = df[400:]

from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler(feature_range = (0, 1))
training_data_scaled = pd.DataFrame(sc.fit_transform(training_data),
              columns=training_data.columns,
              dtype='float64')
validation_data_scaled = pd.DataFrame(sc.transform(validation_data),
              columns=validation_data.columns,
              dtype='float64')
testing_data_scaled = pd.DataFrame(sc.transform(testing_data),
              columns=testing_data.columns,
              dtype='float64')

training_data_scaled
# Out:
#          Open      High       Low     Close
# 0    0.058995  0.065019  0.067026  0.061630
# 1    0.059187  0.059136  0.055288  0.058808
# 2    0.054318  0.063071  0.063241  0.068126
# 3    0.073178  0.075754  0.072608  0.074621
# 4    0.071568  0.070864  0.077961  0.071760
# ..        ...       ...       ...       ...
# 295  0.974393  0.972189  0.958018  0.961027
# 296  0.938475  0.959812  0.934236  0.975139
# 297  0.964657  0.964893  0.935306  0.939878
# 298  0.915130  0.927379  0.911906  0.908444
# 299  0.909610  0.939260  0.922574  0.945755
#
# [300 rows x 4 columns]

# %%
import itertools

def discrete_frac_range():

        # increment : 0.01
        # fracchange : from -0.1 to 0.1, total 20 points
        # frachigh : from 0 to 0.1, total 10 points
        # fraclow : from 0 to 0.1, total 10 points

        frac_change_list = np.linspace(-0.1, 0.1, 20)
        frac_high_list = np.linspace(0, 0.1, 10)
        frac_low_list = np.linspace(0, 0.1, 10)
        
        return np.array(list(itertools.product(\
                    frac_change_list, frac_high_list, frac_low_list))) 
    
all_discrete_fracs = discrete_frac_range()
all_discrete_fracs
# Out:
# array([[-0.1       ,  0.        ,  0.        ],
#        [-0.1       ,  0.        ,  0.01111111],
#        [-0.1       ,  0.        ,  0.02222222],
#        ...,
#        [ 0.1       ,  0.1       ,  0.07777778],
#        [ 0.1       ,  0.1       ,  0.08888889],
#        [ 0.1       ,  0.1       ,  0.1       ]])

# %%
def fraction_calculator(data):

        open = np.array(data['Open'])
        close = np.array(data['Close'])
        high = np.array(data['High'])
        low = np.array(data['Low'])

        frac_change = (close - open) / open
        frac_high = (high - open) / open
        frac_low = (open - low) / open

        return np.column_stack((frac_change, frac_high, frac_low))

example_frac = fraction_calculator(df.head())
example_frac
# Out:
# array([[-0.00092462,  0.00535734,  0.00660829],
#        [-0.00304538,  0.00103325,  0.01509095],
#        [ 0.00698499,  0.00731241,  0.00600273],
#        [-0.00183081,  0.00290776,  0.01257337],
#        [-0.00269542,  0.00059299,  0.00768194]])

# %%
from hmmlearn.hmm import GaussianHMM

hmm = GaussianHMM(n_components=4)
#        [ 2.36011577e-03,  2.61852260e-03,  8.32070011e-03],
#        [-1.35436311e-03,  1.11434939e-03,  6.63466484e-03],
#        [ 1.55183116e-04,  2.20704876e-03,  4.79343403e-03],
#        [-2.35968723e-02,  2.22415291e-03,  2.43266725e-02],
#        [-2.20761922e-02,  3.55208241e-04,  3.89130628e-02],
#        [ 1.14201311e-02,  1.39059010e-02,  3.42243677e-04],
#        [-1.09014225e-02,  2.35899635e-03,  1.76031167e-02],
#        [-8.33231436e-03,  6.58549793e-03,  1.54593254e-02],
#        [ 8.21281609e-03,  1.29765909e-02,  1.72452063e-02],
#        [-3.88059701e-02,  2.13704206e-03,  4.00271370e-02],
#        [ 9.85013720e-04,  1.57953986e-02,  3.51790614e-05],
#        [-1.10095591e-03,  5.50477955e-03,  1.43648533e-02],
#        [ 7.66196987e-03,  7.83571069e-03,  3.10996056e-03],
#        [ 8.39299784e-03,  8.78695488e-03,  6.06351273e-03],
#        [ 9.55794504e-04,  9.04591227e-03,  2.37241850e-03],
#        [ 8.61002356e-03,  1.00337282e-02,  6.62700632e-03],
#        [-1.95121951e-03,  8.41042893e-04,  6.40874685e-03],
#        [ 1.62098987e-02,  1.62098987e-02,  9.31603374e-04],
#        [ 6.02208096e-03,  7.36032118e-03,  2.34192037e-03],
#        [ 7.82368412e-03,  9.47165163e-03,  1.23181410e-03],
#        [-2.45582013e-03,  3.25230233e-03,  6.47141790e-03],
#        [ 7.97912130e-04,  3.12515584e-03,  2.42698273e-03],
#        [-3.31180659e-03,  1.70558039e-03,  4.10664017e-03],
#        [ 5.94013407e-03,  1.22784894e-02,  2.15703192e-04],
#        [ 4.11522634e-03,  7.81893004e-03,  3.76954733e-03],
#        [-3.13725490e-03,  3.98692810e-03,  8.36601307e-03],
#        [ 1.56083135e-03,  5.70114187e-03,  2.46447055e-04],
#        [-3.83499680e-03,  3.16305292e-03,  1.15705459e-02],
#        [-2.96785104e-03,  1.30983370e-03,  1.17056024e-02],
#        [-6.58436214e-05,  8.23045267e-04,  4.52674897e-03],
#        [ 2.68312757e-03,  6.65020576e-03,  2.94650206e-03],
#        [-2.19262362e-03,  3.17439539e-03,  3.01076676e-03],
#        [-9.45857795e-03,  4.89236791e-04,  1.21983040e-02],
#        [-3.38904975e-03,  1.61226639e-03,  9.54198473e-03],
#        [-1.07498516e-02,  1.05520016e-03,  1.35197520e-02],
#        [ 1.08850373e-02,  1.13371850e-02,  8.45683664e-03],
#        [-1.56462135e-02,  2.10271863e-03,  1.92059340e-02],
#        [-7.88414036e-03,  7.39349643e-03,  8.12100294e-03],
#        [ 1.09053289e-02,  1.51283878e-02,  9.66724331e-04]])

# %%
def most_likely_fracs(curr_date, hmm, all_discrete_fracs, testing_data):

        start_date = max(0, curr_date - 10)
        end_date = max(0, curr_date - 1)

        previous_data = testing_data.iloc[end_date: start_date]
        previous_fracs = fraction_calculator(previous_data)

        all_probs = []
        for one_fracs in all_discrete_fracs:
            one_outcome = np.row_stack((previous_fracs, one_fracs))
            all_probs.append(hmm.score(one_outcome))

        max_prob = all_discrete_fracs[np.argmax(all_probs)]

        return max_prob

ex_likely_frac = most_likely_fracs(20, hmm, all_discrete_fracs, testing_data)
ex_likely_frac
# Out:
# array([0.00526316, 0.01111111, 0.01111111])

# %%
def close_price(date, testing_data, most_likely_fracs, hmm, all_discrete_fracs):
                         
        open = testing_data.iloc[date]['Open']                   
        likely_frac_change, _, _ = most_likely_fracs(date, hmm, all_discrete_fracs, testing_data)     
        close = open * (1 + likely_frac_change)
        return close, (open + close) / 2

calc_close_price, calc_middle_price = close_price(20, testing_data, most_likely_fracs, hmm, all_discrete_fracs)
calc_close_price, calc_middle_price
# Out:
# (602.2933684210526, 600.7166842105263)

# %%
def closing_and_middle_price_in_range(testing_data, most_likely_fracs, hmm, all_discrete_fracs):

        # for all rows in testing data
        closing_prices = []
        middle_prices = []
        #calc_close_price, calc_middle_price = close_price(20, testing_data, most_likely_fracs, hmm, all_discrete_fracs)
        for date in range(testing_data.shape[0]):
            close, middle = close_price(date, testing_data, most_likely_fracs, hmm, all_discrete_fracs)
            closing_prices.append(close)
            middle_prices.append(middle)
        
        return closing_prices, middle_prices
  
_, mid_price_train = closing_and_middle_price_in_range(training_data, most_likely_fracs, hmm, all_discrete_fracs)
_, mid_price_validate = closing_and_middle_price_in_range(validation_data, most_likely_fracs, hmm, all_discrete_fracs)
_, mid_price_test = closing_and_middle_price_in_range(testing_data, most_likely_fracs, hmm, all_discrete_fracs)
mid_price_train, mid_price_validate, mid_price_test
# Out:
# ([368.68768421052636,
#   368.73781578947364,
#   367.46447368421053,
#   372.39742105263156,
#   371.9763157894737,
#   369.4897894736842,
#   360.6064736842105,
#   362.1505263157895,
#   359.8043684210527,
#   356.1146842105263,
#   353.2571842105263,
#   368.9684210526316,
#   371.5953157894737,
#   376.36784210526315,
#   376.8691578947369,
#   374.36257894736843,
#   377.86176315789476,
#   376.24752631578946,
#   380.09763157894736,
#   384.85010526315784,
#   381.56147368421057,
#   380.53878947368423,
#   385.86276315789473,
#   391.08647368421055,
#   390.2242105263158,
#   391.6078421052631,
#   391.08647368421055,
#   390.88594736842106,
#   394.7360526315789,
#   399.0473684210526,
#   403.70960526315787,
#   400.05,
#   400.6816578947369,
#   402.2056578947368,
#   398.54605263157896,
#   398.44578947368416,
#   401.6040789473684,
#   399.98984210526316,
#   403.70960526315787,
#   415.59078947368425,
#   421.62663157894735,
#   418.12744736842103,
#   418.34802631578947,
#   416.93431578947366,
#   416.453052631579,
#   415.03934210526313,
#   414.16705263157894,
#   410.32697368421054,
#   403.5592105263158,
#   406.6874210526316,
#   409.49478947368425,
#   406.7074736842105,
#   408.44202631578946,
#   407.26894736842104,
#   407.8203947368421,
#   404.3813684210526,
#   403.0578947368421,
#   398.54605263157896,
#   403.3286052631579,
#   407.8003421052632,
#   403.78981578947366,
#   394.0642894736842,
#   390.44478947368424,
#   388.77039473684215,
#   392.4701052631579,
#   397.4832631578947,
#   530.6126842105264,
#   527.6749736842105,
#   537.3102631578947,
#   531.2543684210527,
#   528.828,
#   525.1383157894736,
#   514.9515789473685,
#   501.1754210526316,
#   517.3478684210527,
#   518.3505,
#   521.9800263157895,
#   535.9166052631579,
#   540.2379473684211,
#   538.3429736842105])

# %%
plt.figure(figsize = (30,9))
plt.plot(range(testing_data.shape[0]), testing_data['Middle'], label='Actual')
plt.plot(range(testing_data.shape[0]), mid_price_test, label='Prediction')
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.title("Testing", fontsize=40)
leg = plt.legend(prop={'size': 30})
plt.show()

# %%
plt.figure(figsize = (30,9))
plt.plot(range(validation_data.shape[0]), validation_data['Middle'], label='Actual')
plt.plot(range(validation_data.shape[0]), mid_price_validate, label='Prediction')
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.title("Validation", fontsize=40)
leg = plt.legend(prop={'size': 30})
plt.show()

# %%
plt.figure(figsize = (30,9))
plt.plot(range(training_data.shape[0]), training_data['Middle'], label='Actual')
plt.plot(range(training_data.shape[0]), mid_price_train, label='Prediction')
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.title("Training", fontsize=40)
leg = plt.legend(prop={'size': 30})
plt.show()

# %%
df = pd.read_csv('dataset/news_sentiment_augmented_google.csv').drop(['Unnamed: 0'], axis=1)
df['Middle'] = (df['Low'] + df['High']) / 2
df
# Out:
#            Date  data_channel_is_lifestyle  data_channel_is_entertainment  \
# 0      1/7/2013                   0.101266                       0.088608
# 1      1/8/2013                   0.083333                       0.166667
# 2      1/9/2013                   0.134831                       0.191011
# 3     1/10/2013                   0.125000                       0.187500
# 4     1/11/2013                   0.098039                       0.137255
# ..          ...                        ...                            ...
# 493  12/19/2014                   0.067568                       0.121622
# 494  12/22/2014                   0.097222                       0.097222
# 495  12/23/2014                   0.049180                       0.163934
# 496  12/24/2014                   0.057692                       0.115385
# 497  12/26/2014                   0.073171                       0.073171
#
#      data_channel_is_bus  data_channel_is_socmed  data_channel_is_tech  \
# 0               0.113924                0.050633              0.455696
# 1               0.083333                0.000000              0.416667
# 2               0.112360                0.033708              0.235955
# 3               0.200000                0.012500              0.237500
# 4               0.078431                0.058824              0.333333
# ..                   ...                     ...                   ...
# 493             0.121622                0.040541              0.081081
# 494             0.125000                0.013889              0.083333
# 495             0.032787                0.016393              0.131148
# 496             0.076923                0.057692              0.115385
# 497             0.097561                0.000000              0.121951
#
#      data_channel_is_world  global_subjectivity  global_sentiment_polarity  \
# 0                 0.113924             0.480690                   0.176541
# 1                 0.166667             0.455641                   0.161938
# 2                 0.123596             0.467116                   0.145615
# 3                 0.062500             0.462260                   0.156578
# 4                 0.156863             0.480836                   0.166839
# ..                     ...                  ...                        ...
# 493               0.432432             0.349775                   0.093596
# 494               0.319444             0.384586                   0.092461
# 495               0.377049             0.377784                   0.065058
# 496               0.423077             0.352430                   0.079892
# 497               0.463415             0.383164                   0.085894
#
#      global_rate_positive_words  ...  abs_title_subjectivity  \
# 0                      0.052167  ...                0.329081
# 1                      0.048414  ...                0.338889
# 2                      0.046497  ...                0.385071
# 3                      0.047305  ...                0.389721
# 4                      0.043516  ...                0.329093
# ..                          ...  ...                     ...
# 493                    0.029660  ...                0.340203
# 494                    0.029623  ...                0.335687
# 495                    0.030542  ...                0.316924
# 496                    0.027218  ...                0.363923
# 497                    0.028703  ...                0.305868
#
#      abs_title_sentiment_polarity       shares    Open    High     Low  \
# 0                        0.176808  2004.556962  367.72  369.69  365.29
# 1                        0.102778  1493.583333  367.77  368.15  362.22
# 2                        0.159139  2536.303371  366.50  369.18  364.30
# 3                        0.096425  2085.200000  371.42  372.50  366.75
# 4                        0.186686  3621.843137  371.00  371.22  368.15
# ..                            ...          ...     ...     ...     ...
# 493                      0.138859  2476.770270  516.99  520.81  508.86
# 494                      0.181722  2348.555556  520.61  532.97  520.59
# 495                      0.136902  2862.983607  534.51  542.30  533.72
# 496                      0.132746  3544.038462  538.82  540.29  535.10
# 497                      0.189816  3072.975610  536.93  543.25  535.49
#
#       Close   Volume  OpenInt   Middle
# 0    367.38  3311534        0  367.490
# 1    366.65  3352074        0  365.185
# 2    369.06  4051302        0  366.740
# 3    370.74  3671560        0  369.625
# 4    370.00  2570250        0  369.685
# ..      ...      ...      ...      ...
# 493  520.04  4872059        0  514.835
# 494  532.30  3319461        0  526.780
# 495  538.77  2877208        0  538.010
# 496  536.93   737848        0  537.695
# 497  541.52  1113464        0  539.370
#
# [498 rows x 31 columns]

# %%
plt.figure(figsize = (30,9))
plt.plot(range(df.shape[0]), df['Middle'])
plt.xticks(range(0, df.shape[0], 359), df['Date'].loc[::30])
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.show()

# %%
df = df.drop(['Date'], axis=1)

# %%
training_data = df[:300]
validation_data = df[300:400]
testing_data = df[400:]

from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler(feature_range = (0, 1))
training_data_scaled = pd.DataFrame(sc.fit_transform(training_data),
              columns=training_data.columns,
              dtype='float64')
validation_data_scaled = pd.DataFrame(sc.transform(validation_data),
              columns=validation_data.columns,
              dtype='float64')
testing_data_scaled = pd.DataFrame(sc.transform(testing_data),
              columns=testing_data.columns,
              dtype='float64')

training_data_scaled
# Out:
#      data_channel_is_lifestyle  data_channel_is_entertainment  \
# 0                     0.543153                       0.227605
# 1                     0.446970                       0.512821
# 2                     0.723187                       0.601772
# 3                     0.670455                       0.588942
# 4                     0.525847                       0.405354
# ..                         ...                            ...
# 295                   0.259531                       0.434243
# 296                   0.175857                       0.502837
# 297                   0.167614                       0.417668
# 298                   0.000000                       0.190422
# 299                   0.272727                       0.151565
#
#      data_channel_is_bus  data_channel_is_socmed  data_channel_is_tech  \
# 0               0.197980                0.199553              0.787121
# 1               0.103237                0.000000              0.710903
# 2               0.193135                0.132849              0.358002
# 3               0.464567                0.049265              0.361019
# 4               0.088055                0.231834              0.548166
# ..                   ...                     ...                   ...
# 295             0.144865                0.190702              0.369681
# 296             0.555957                0.129219              0.217357
# 297             0.377461                0.184743              0.324403
# 298             0.452421                0.231834              0.126965
# 299             0.212598                0.400798              0.393704
#
#      data_channel_is_world  global_subjectivity  global_sentiment_polarity  \
# 0                 0.265384             0.801997                   0.838543
# 1                 0.404290             0.518249                   0.697056
# 2                 0.290855             0.648240                   0.538887
# 3                 0.129950             0.593227                   0.645117
# 4                 0.378470             0.803651                   0.744541
# ..                     ...                  ...                        ...
# 295               0.602523             0.449170                   0.183346
# 296               0.656143             0.493522                   0.186564
# 297               0.582611             0.363386                   0.105685
# 298               0.430111             0.536312                   0.256711
# 299               0.724199             0.630113                   0.339273
#
#      global_rate_positive_words  global_rate_negative_words  ...  \
# 0                      1.000000                    0.286567  ...
# 1                      0.798920                    0.219626  ...
# 2                      0.696144                    0.198793  ...
# 3                      0.739473                    0.433560  ...
# 4                      0.536400                    0.377849  ...
# ..                          ...                         ...  ...
# 295                    0.356334                    0.670336  ...
# 296                    0.352439                    0.599635  ...
# 297                    0.190029                    0.425558  ...
# 298                    0.165015                    0.429428  ...
# 299                    0.307493                    0.388371  ...
#
#      abs_title_subjectivity  abs_title_sentiment_polarity    shares      Open  \
# 0                  0.591883                      0.529864  0.032107  0.058995
# 1                  0.642715                      0.143875  0.000000  0.059187
# 2                  0.882067                      0.437738  0.065519  0.054318
# 3                  0.906167                      0.110753  0.037174  0.073178
# 4                  0.591947                      0.581366  0.133728  0.071568
# ..                      ...                           ...       ...       ...
# 295                0.479048                      0.570092  0.219141  0.974393
# 296                0.498946                      0.382707  0.029149  0.938475
# 297                0.716110                      0.193989  0.069501  0.964657
# 298                0.562241                      0.822544  0.092753  0.915130
# 299                0.670538                      0.338688  0.101374  0.909610
#
#          High       Low     Close    Volume  OpenInt    Middle
# 0    0.065019  0.067026  0.061630  0.084954      0.0  0.066194
# 1    0.059136  0.055288  0.058808  0.086823      0.0  0.057362
# 2    0.063071  0.063241  0.068126  0.119051      0.0  0.063320
# 3    0.075754  0.072608  0.074621  0.101548      0.0  0.074375
# 4    0.070864  0.077961  0.071760  0.050788      0.0  0.074605
# ..        ...       ...       ...       ...      ...       ...
# 295  0.972189  0.958018  0.961027  0.090454      0.0  0.967621
# 296  0.959812  0.934236  0.975139  0.113638      0.0  0.949497
# 297  0.964893  0.935306  0.939878  0.148548      0.0  0.952582
# 298  0.927379  0.911906  0.908444  0.144505      0.0  0.922042
# 299  0.939260  0.922574  0.945755  0.132039      0.0  0.933346
#
# [300 rows x 30 columns]

# %%
def discrete_frac_range_news():

        # increment : 0.01
        # fracchange : from -0.1 to 0.1, total 20 points
        # frachigh : from 0 to 0.1, total 10 points
        # fraclow : from 0 to 0.1, total 10 points

        #frac_change_list = np.linspace(-0.1, 0.1, 20)
        frac_high_list = np.linspace(0, 0.1, 10)
        frac_low_list = np.linspace(0, 0.1, 10)
        frac_news = np.linspace(-0.1, 0.1, 20)
        
        
        return np.array(list(itertools.product(\
                    frac_news, frac_high_list, frac_low_list))) 
    
all_discrete_fracs_news = discrete_frac_range_news()
all_discrete_fracs_news
# Out:
# array([[-0.1       ,  0.        ,  0.        ],
#        [-0.1       ,  0.        ,  0.01111111],
#        [-0.1       ,  0.        ,  0.02222222],
#        ...,
#        [ 0.1       ,  0.1       ,  0.07777778],
#        [ 0.1       ,  0.1       ,  0.08888889],
#        [ 0.1       ,  0.1       ,  0.1       ]])

# %%
def fraction_calculator_news(data):

        open = np.array(data['Open'])
        close = np.array(data['Close'])
        high = np.array(data['High'])
        low = np.array(data['Low'])

        #frac_change = (close - open) / open
        frac_high = (high - open) / open
        frac_low = (open - low) / open
        frac_news = ((close - open) / open) * data['abs_title_sentiment_polarity']

        return np.column_stack((frac_news, frac_high, frac_low))

example_frac_news = fraction_calculator_news(df.head())
example_frac_news
# Out:
# array([[-0.00016348,  0.00535734,  0.00660829],
#        [-0.000313  ,  0.00103325,  0.01509095],
#        [ 0.00111159,  0.00731241,  0.00600273],
#        [-0.00017654,  0.00290776,  0.01257337],
#        [-0.0005032 ,  0.00059299,  0.00768194]])

# %%
hmm_news = GaussianHMM(n_components=4)
frac_vector_news = fraction_calculator_news(training_data)
hmm_news.fit(frac_vector_news)
# Out:
# GaussianHMM(algorithm='viterbi', covariance_type='diag', covars_prior=0.01,
#             covars_weight=1, init_params='stmc', means_prior=0, means_weight=0,
#             min_covar=0.001, n_components=4, n_iter=10, params='stmc',
#             random_state=None, startprob_prior=1.0, tol=0.01,
#             transmat_prior=1.0, verbose=False)

# %%
def most_likely_fracs_news(curr_date, hmm, all_discrete_fracs, testing_data):

        start_date = max(0, curr_date - 10)
        end_date = max(0, curr_date - 1)

        previous_data = testing_data.iloc[end_date: start_date]
        previous_fracs = fraction_calculator_news(previous_data)

        all_probs = []
        for one_fracs in all_discrete_fracs:
            one_outcome = np.row_stack((previous_fracs, one_fracs))
            all_probs.append(hmm.score(one_outcome))

        max_prob = all_discrete_fracs_news[np.argmax(all_probs)]

        return max_prob

ex_likely_frac_news = most_likely_fracs_news(20, hmm_news, all_discrete_fracs_news, testing_data)
ex_likely_frac_news
# Out:
# array([0.00526316, 0.01111111, 0.01111111])

# %%
def close_price_news(date, testing_data, most_likely_fracs, hmm, all_discrete_fracs):
                         
        open = testing_data.iloc[date]['Open']   
        news = testing_data.iloc[date]['abs_title_sentiment_polarity']
        likely_frac_news, _, _ = most_likely_fracs_news(date, hmm, all_discrete_fracs, testing_data)     
        #close = open * (1 + likely_frac_change)
        close_news = open * (1 + (likely_frac_news / news))
        return close_news, (open + close_news) / 2

calc_close_news, calc_middle_news = close_price_news(20, testing_data, most_likely_fracs_news, hmm_news, all_discrete_fracs_news)
calc_close_news, calc_middle_news
# Out:
# (622.7430217099422, 610.941510854971)

# %%
def closing_and_middle_price_in_range_news(testing_data, most_likely_fracs, hmm, all_discrete_fracs):

        # for all rows in testing data
        #closing_prices = []
        #middle_prices = []
        close_news_prices = []
        mid_news_prices = []
        #calc_close_price, calc_middle_price = close_price(20, testing_data, most_likely_fracs, hmm, all_discrete_fracs)
        for date in range(testing_data.shape[0]):
            close_news, mid_news = close_price_news(date, testing_data, most_likely_fracs, hmm, all_discrete_fracs)
            #closing_prices.append(close)
            #middle_prices.append(middle)
            close_news_prices.append(close_news)
            mid_news_prices.append(mid_news)
        
        return close_news_prices, mid_news_prices
  
_, mid_price_train_news = closing_and_middle_price_in_range_news(training_data, most_likely_fracs_news, hmm_news, all_discrete_fracs_news)
_, mid_price_validate_news = closing_and_middle_price_in_range_news(validation_data, most_likely_fracs_news, hmm_news, all_discrete_fracs_news)
_, mid_price_test_news = closing_and_middle_price_in_range_news(testing_data, most_likely_fracs_news, hmm_news, all_discrete_fracs_news)
mid_price_train_news, mid_price_validate_news, mid_price_test_news
# Out:
# ([373.19306948831627,
#   377.1865860393837,
#   372.56057235250887,
#   381.5565738845643,
#   376.2297161856144,
#   374.64913978374346,
#   366.1110803410407,
#   368.74503996882777,
#   368.4782969862225,
#   360.7539146366721,
#   357.9348016808302,
#   375.35757979475926,
#   590.3131550015147,
#   598.6809691122255,
#   608.0518540252724,
#   608.2893597235411,
#   612.0019165089197,
#   602.7117634215836,
#   600.1549555102868,
#   604.8931844022019,
#   596.0516590702301,
#   589.2978859309798,
#   598.8883508414563,
#   594.7333814952501,
#   588.8841375210118,
#   592.0661976446718,
#   601.5922139553962,
#   594.04687241123,
#   583.5573316270261,
#   590.8913680598323,
#   576.0713828239859,
#   566.3887598000504,
#   559.3238262865025,
#   551.8807882147237,
#   533.7550369868359,
#   552.7886726259408,
#   527.6942626723685,
#   549.1320724448325,
#   549.1409758242955,
#   558.5358590519251,
#   563.4196688213734,
#   556.5956676862709,
#   560.7903944668983,
#   570.1129372900031,
#   569.9266793569884,
#   578.3696100180337,
#   575.3444626824838,
#   569.2334139255303,
#   579.5990512865374,
#   564.7561024645418,
#   566.5637486815046,
#   561.1007917688378,
#   567.0235216517638,
#   571.338602130678,
#   571.1848208946762,
#   566.7623856289458,
#   564.7480448548381,
#   556.1777752503452,
#   553.6572554663467,
#   551.4264617054098,
#   559.7391450516426,
#   554.7729292261363,
#   556.1589384011795,
#   559.4061792578611,
#   561.8479841799858,
#   554.0821405708823,
#   547.8118545752827,
#   547.1776609494541,
#   544.5962614099753,
#   545.6576339095695,
#   537.061442150555,
#   535.2793953963109,
#   543.8143720461876,
#   540.2963502197861,
#   535.9233087172732,
#   532.1911935016489,
#   523.03852886608,
#   508.26028051552515,
#   525.6904159913768,
#   526.7877218730306,
#   528.149118085786,
#   544.7845249378163,
#   549.5016800144741,
#   544.3739014228211])

# %%
plt.figure(figsize = (30,9))
plt.plot(range(testing_data.shape[0]), testing_data['Middle'], label='Actual')
plt.plot(range(testing_data.shape[0]), mid_price_test_news, label='Prediction News')
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.title("Testing", fontsize=40)
leg = plt.legend(prop={'size': 30})
plt.show()

# %%
plt.figure(figsize = (30,9))
plt.plot(range(validation_data.shape[0]), validation_data['Middle'], label='Actual')
plt.plot(range(validation_data.shape[0]), mid_price_validate_news, label='Prediction News')
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.title("Validation", fontsize=40)
leg = plt.legend(prop={'size': 30})
plt.show()

# %%
plt.figure(figsize = (30,9))
plt.plot(range(training_data.shape[0]), training_data['Middle'], label='Actual')
plt.plot(range(training_data.shape[0]), mid_price_train_news, label='Prediction News')
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.title("Training", fontsize=40)
leg = plt.legend(prop={'size': 30})
plt.show()

# %%
plt.figure(figsize = (30,9))
plt.plot(range(testing_data.shape[0]), testing_data['Middle'], label='Actual')
plt.plot(range(testing_data.shape[0]), mid_price_test, label='Prediction Base')
plt.plot(range(testing_data.shape[0]), mid_price_test_news, label='Prediction News')
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.title("HMM Testing", fontsize=40)
leg = plt.legend(prop={'size': 30})
plt.show()

# %%
plt.figure(figsize = (30,9))
plt.plot(range(validation_data.shape[0]), validation_data['Middle'], label='Actual')
plt.plot(range(validation_data.shape[0]), mid_price_validate, label='Prediction Base')
plt.plot(range(validation_data.shape[0]), mid_price_validate_news, label='Prediction News')
plt.xlabel('Date', fontsize=30)
plt.ylabel('Mid Price', fontsize=30)
plt.title("HMM Validation", fontsize=40)
leg = plt.legend(prop={'size': 30})
plt.show()

# %%
from sklearn.metrics import r2_score

print(r2_score(training_data['Middle'], mid_price_train))
print(r2_score(training_data['Middle'], mid_price_train_news))
print(r2_score(validation_data['Middle'], mid_price_validate))
print(r2_score(validation_data['Middle'], mid_price_validate_news))
print(r2_score(testing_data['Middle'], mid_price_test))
print(r2_score(testing_data['Middle'], mid_price_test_news))
# Out:
# 0.9785608919323971
# 0.8111801266591462
